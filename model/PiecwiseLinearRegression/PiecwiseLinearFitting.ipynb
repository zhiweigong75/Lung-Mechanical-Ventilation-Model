# %%
import numpy as np
import matplotlib.pyplot as plt
import pwlf
import pandas as pd

# %%
# import PEEP7_RR12_CT0.01_PaO25
data1 = pd.read_excel('PEEP7_RR12_CT0.01_PaO25.xlsx')
volume1 = data1['Volume']
flow1 = data1['Flow']
pressure1 = data1['Pressure']
time1 = data1['Time']

# import PEEP7_RR13_CT0.01_PaO25
data2 = pd.read_excel('PEEP7_RR13_CT0.01_PaO25.xlsx')
volume2 = data2['Volume']
flow2 = data2['Flow']
pressure2 = data2['Pressure']
time2 = data2['Time']

# import PEEP7_RR14_CT0.01_PaO25
data3 = pd.read_excel('PEEP7_RR14_CT0.01_PaO25.xlsx')
volume3 = data3['Volume']
flow3 = data3['Flow']
pressure3 = data3['Pressure']
time3 = data3['Time']

# import PEEP7_RR15_CT0.01_PaO25
data4 = pd.read_excel('PEEP7_RR15_CT0.01_PaO25.xlsx')
volume4 = data4['Volume']
flow4 = data4['Flow']
pressure4 = data4['Pressure']
time4 = data4['Time']

# import PEEP7_RR16_CT0.01_PaO25
data5 = pd.read_excel('PEEP7_RR16_CT0.01_PaO25.xlsx')
volume5 = data5['Volume']
flow5 = data5['Flow']
pressure5 = data5['Pressure']
time5 = data5['Time']

# %%
# PEEP7_RR12
# First repetition
y1 = pressure1[0:501]
x1 = time1[0:501]
my_pwlf = pwlf.PiecewiseLinFit(x1, y1)
res = my_pwlf.fit(4)
# predict for the determined points
# xHat = np.linspace(min(x), max(x), num=10000)
xHat = x1
yHat = my_pwlf.predict(xHat)

breakpoints = my_pwlf.fit_breaks
# coefs = my_pwlf.fit_coefficients
print(breakpoints)
# print(coefs)

# plot the results
plt.figure()
plt.plot(x1, y1, 'o')
plt.plot(xHat, yHat, '-')
plt.show()
# Out:
# [0.         0.125025   0.83466129 0.8380589  5.        ]

# %%
# PEEP7_RR12
# whole repetition (2 rep)
y1 = pressure1
x1 = time1
my_pwlf = pwlf.PiecewiseLinFit(x1, y1)
res = my_pwlf.fit(8)
# predict for the determined points
# xHat = np.linspace(min(x), max(x), num=10000)
xHat = x1
yHat = my_pwlf.predict(xHat)

breakpoints = my_pwlf.fit_breaks
# coefs = my_pwlf.fit_coefficients
print(breakpoints)
# print(coefs)

# plot the results
plt.figure()
plt.plot(x1, y1, 'o')
plt.plot(xHat, yHat, '-')
plt.show()
# Out:
# [ 0.          0.125025    0.83932802  0.83937845  5.          5.125025
#   5.83035457  5.83933361 10.        ]

# %%
# PEEP7_RR13
# First repetition
y2 = pressure2[0:462]
x2 = time2[0:462]
my_pwlf = pwlf.PiecewiseLinFit(x2, y2)
res = my_pwlf.fit(4)
# predict for the determined points
# xHat = np.linspace(min(x), max(x), num=10000)
xHat = x2
yHat = my_pwlf.predict(xHat)

breakpoints = my_pwlf.fit_breaks
# coefs = my_pwlf.fit_coefficients
print(breakpoints)
# print(coefs)

# plot the results
plt.figure()
plt.plot(x2, y2, 'o')
plt.plot(xHat, yHat, '-')
plt.show()
# Out:
# [0.         0.11540769 0.76043237 0.76853062 4.61      ]

# %%
# PEEP7_RR13
# whole repetition (near 3 rep)
y2 = pressure2
x2 = time2
my_pwlf = pwlf.PiecewiseLinFit(x2, y2)
res = my_pwlf.fit(10, atol=0.01)
# predict for the determined points
# xHat = np.linspace(min(x), max(x), num=10000)
xHat = x2
yHat = my_pwlf.predict(xHat)

breakpoints = my_pwlf.fit_breaks
# coefs = my_pwlf.fit_coefficients
print(breakpoints)
# print(coefs)

# plot the results
plt.figure()
plt.plot(x2, y2, 'o')
plt.plot(xHat, yHat, '-')
plt.show()

# rom scipy.optimize import minimize
# model.use_custom_opt(2)
# guess = [5.0] # guess the breakpoint location
# res = minimize(model.fit_with_breaks_opt, guess)
# Out:
# [ 0.          0.11540769  0.7621803   0.76457562  4.61538461  4.73079231
#   5.38435872  5.38667863  9.23076923  9.34617692 10.        ]

# %%
# PEEP7_RR14
# First repetition
y3 = pressure3[0:429]
x3 = time3[0:429]
my_pwlf = pwlf.PiecewiseLinFit(x3, y3)
res = my_pwlf.fit(4, atol=0.01)
# predict for the determined points
# xHat = np.linspace(min(x), max(x), num=10000)
xHat = x3
yHat = my_pwlf.predict(xHat)

breakpoints = my_pwlf.fit_breaks
# coefs = my_pwlf.fit_coefficients
print(breakpoints)
# print(coefs)

# plot the results
plt.figure()
plt.plot(x3, y3, 'o')
plt.plot(xHat, yHat, '-')
plt.show()
# Out:
# [0.         0.10716009 0.71379949 0.71509776 4.28      ]

# %%
# PEEP7_RR14
# whole repetition (near 3 rep)
y3 = pressure3
x3 = time3
my_pwlf = pwlf.PiecewiseLinFit(x3, y3)
res = my_pwlf.fit(12, atol=0.001)
# predict for the determined points
# xHat = np.linspace(min(x), max(x), num=10000)
xHat = x3
yHat = my_pwlf.predict(xHat)

breakpoints = my_pwlf.fit_breaks
# coefs = my_pwlf.fit_coefficients
print(breakpoints)
# print(coefs)

# plot the results
plt.figure()
plt.plot(x3, y3, 'o')
plt.plot(xHat, yHat, '-')
plt.show()
# Out:
# [ 0.          0.10716428  0.71466563  0.71530826  4.28571427  4.39287855
#   5.00229405  5.00391873  8.57142865  8.67859297  9.28122711  9.2881345
#  10.        ]

# %%
# PEEP7_RR15
# First repetition
y4 = pressure4[0:401]
x4 = time4[0:401]
my_pwlf = pwlf.PiecewiseLinFit(x4, y4)
res = my_pwlf.fit(4, atol=0.01)
# predict for the determined points
# xHat = np.linspace(min(x), max(x), num=10000)
xHat = x4
yHat = my_pwlf.predict(xHat)

breakpoints = my_pwlf.fit_breaks
# coefs = my_pwlf.fit_coefficients
print(breakpoints)
# print(coefs)

# plot the results
plt.figure()
plt.plot(x4, y4, 'o')
plt.plot(xHat, yHat, '-')
plt.show()
# Out:
# [0.         0.10001999 0.66096499 0.66416571 4.        ]

# %%
# PEEP7_RR15
# whole repetition
y4 = pressure4
x4 = time4
my_pwlf = pwlf.PiecewiseLinFit(x4, y4)
res = my_pwlf.fit(12, atol=0.0001)
# predict for the determined points
# xHat = np.linspace(min(x), max(x), num=10000)
xHat = x4
yHat = my_pwlf.predict(xHat)

breakpoints = my_pwlf.fit_breaks
# coefs = my_pwlf.fit_coefficients
print(breakpoints)
# print(coefs)

# plot the results
plt.figure()
plt.plot(x4, y4, 'o')
plt.plot(xHat, yHat, '-')
plt.show()
# Out:
# [ 0.          0.10001998  0.66332132  0.66984603  4.00000003  4.10001999
#   4.66105248  4.6621577   8.          8.10001999  8.6691084   8.66989202
#  10.        ]

# %%
# PEEP7_RR16
# First repetition
y5 = pressure5[0:376]
x5 = time5[0:376]
my_pwlf = pwlf.PiecewiseLinFit(x5, y5)
res = my_pwlf.fit(4, atol=0.01)
# predict for the determined points
# xHat = np.linspace(min(x), max(x), num=10000)
xHat = x5
yHat = my_pwlf.predict(xHat)

breakpoints = my_pwlf.fit_breaks
# coefs = my_pwlf.fit_coefficients
print(breakpoints)
# print(coefs)

# plot the results
plt.figure()
plt.plot(x5, y5, 'o')
plt.plot(xHat, yHat, '-')
plt.show()
# Out:
# [0.         0.09377855 0.62342027 0.62865156 3.75      ]

# %%
# PEEP7_RR16
# whole repetition
y5 = pressure5
x5 = time5
my_pwlf = pwlf.PiecewiseLinFit(x5, y5)
res = my_pwlf.fit(12, atol=0.0001)
# predict for the determined points
# xHat = np.linspace(min(x), max(x), num=10000)
xHat = x5
yHat = my_pwlf.predict(xHat)

breakpoints = my_pwlf.fit_breaks
# coefs = my_pwlf.fit_coefficients
print(breakpoints)
# print(coefs)

# plot the results
plt.figure()
plt.plot(x5, y5, 'o')
plt.plot(xHat, yHat, '-')
plt.show()
# Out:
# [ 0.          0.09376874  0.62102641  0.62917945  3.75        3.84376874
#   4.37242003  4.37728289  7.5         7.59376874  8.12431634  8.12964628
#  10.        ]

# %% [markdown]
#  ## Flow fitting

# %%
# PEEP7_RR12
# First repetition
y1 = flow1[0:501]
x1 = time1[0:501]
my_pwlf = pwlf.PiecewiseLinFit(x1, y1, degree = 4)
res = my_pwlf.fit(6, atol=0.00001)
# predict for the determined points
# xHat = np.linspace(min(x), max(x), num=10000)
xHat = x1
yHat = my_pwlf.predict(xHat)

breakpoints = my_pwlf.fit_breaks
# coefs = my_pwlf.fit_coefficients
print(breakpoints)
# print(coefs)

# plot the results
plt.figure()
plt.plot(x1, y1, 'o')
plt.plot(xHat, yHat, '-')
plt.show()
# Out:
# [0.         0.12404697 0.21199962 0.83750993 0.87015055 0.97136942
#  5.        ]

# %% [markdown]
# ## Volume fitting

# %%
# PEEP7_RR12
# First repetition
y1 = volume1[0:501]
x1 = time1[0:501]
my_pwlf = pwlf.PiecewiseLinFit(x1, y1, degree = 4)
res = my_pwlf.fit(4, atol=0.001)
# predict for the determined points
# xHat = np.linspace(min(x), max(x), num=10000)
xHat = x1
yHat = my_pwlf.predict(xHat)

breakpoints = my_pwlf.fit_breaks
# coefs = my_pwlf.fit_coefficients
print(breakpoints)
# print(coefs)

# plot the results
plt.figure()
plt.plot(x1, y1, 'o')
plt.plot(xHat, yHat, '-')
plt.show()
# Out:
# [0.         0.15651598 0.83269749 0.92939571 5.        ]

# %%
#  Manually give the locations of the breakpoints
my_pwlf_1 = pwlf.PiecewiseLinFit(time, pressure)
x_breaks = np.array([min(time), 0.09, 0.1, 0.62, 0.63, 3.75, 3.76, 3.84, 3.85, 4.37, 4.38, 7.5, 7.51, 7.59, 7.6, 8.12, 8.13, max(time)])
my_pwlf_1.fit_with_breaks(x_breaks)
# res = my_pwlf.fit(13)
# predict for the determined points
# xHat = np.linspace(min(x), max(x), num=10000)
xHat = time
yHat = my_pwlf_1.predict(xHat)

# plot the results
plt.figure()
plt.plot(time, pressure, 'o')
plt.plot(xHat, yHat, '-')
plt.show()
